# %%
print("Hello from MSE800_env!")
# Out:
# Hello from MSE800_env!

# %%
def print_hi(name):
    print(f"Hi, {name}")

name = "sandali"
print_hi(name)
# Out:
# Hi, sandali2

# %%
#Exercise 1:

# Step 1: input 3 test scores (as float values)
test1 = float(input("Enter test score 1: "))
test2 = float(input("Enter test score 2: "))
test3 = float(input("Enter test score 3: "))

# Step 2: Find their average and Assign it in to the result variable.
average = (test1 + test2 + test3) / 3

# Step 3: Print the average result
print("Average score is:", average)
# Out:
# Average score is: 5.0
